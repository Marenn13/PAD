# %%
import pandas as pd
import matplotlib.pyplot as plt

seles  = ['dataPenjualan-Bulanan-2019/Sales_01_January_2019.csv','dataPenjualan-Bulanan-2019/Sales_02_February_2019.csv',
        'dataPenjualan-Bulanan-2019/Sales_03_March_2019.csv','dataPenjualan-Bulanan-2019/Sales_04_April_2019.csv','dataPenjualan-Bulanan-2019/Sales_05_May_2019.csv',
        'dataPenjualan-Bulanan-2019/Sales_06_June_2019.csv','dataPenjualan-Bulanan-2019/Sales_07_July_2019.csv','dataPenjualan-Bulanan-2019/Sales_08_August_2019.csv',
        'dataPenjualan-Bulanan-2019/Sales_09_September_2019.csv','dataPenjualan-Bulanan-2019/Sales_10_October_2019.csv','dataPenjualan-Bulanan-2019/Sales_11_November_2019.csv',
        'dataPenjualan-Bulanan-2019/Sales_12_December_2019.csv']
data = pd.DataFrame()

for file in seles:
    df = pd.read_csv(file,sep=';')
    data = pd.concat([data,df])
    print (data)

#data = pd.concat([pd.read_csv(file) for file in files])
#print(data)
# Out:
#      Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
# 0     141234,iPhone,1,700,01/22/19 21:25,"944 Walnut...
# 1     141235,Lightning Charging Cable,1,14.95,01/28/...
# 2     141236,Wired Headphones,2,11.99,01/17/19 13:33...
# 3     141237,27in FHD Monitor,1,149.99,01/05/19 20:3...
# 4     141238,Wired Headphones,1,11.99,01/25/19 11:59...
# ...                                                 ...
# 9718  150497,20in Monitor,1,109.99,01/26/19 19:09,"9...
# 9719  150498,27in FHD Monitor,1,149.99,01/10/19 22:5...
# 9720  150499,ThinkPad Laptop,1,999.99,01/21/19 14:31...
# 9721  150500,AAA Batteries (4-pack),2,2.99,01/15/19 ...
# 9722  150501,Google Phone,1,600,01/13/19 16:43,"428 ...
#
# [9723 rows x 1 columns]
#       Order ID,Product,Quantity Ordered,Price Each,Order Date,Purchase Address
# 0      141234,iPhone,1,700,01/22/19 21:25,"944 Walnut...
# 1      141235,Lightning Charging Cable,1,14.95,01/28/...
# ...

# %%
# 2. Menghapus data yang mengandung nilai Nan
data =data.dropna()
